# %%
import pandas as pd
from matplotlib import rc as rc
from matplotlib import pyplot as plt
import numpy as np 
from matplotlib.lines import Line2D
import seaborn as sns
user = "maria"
K = 50
n_inits = 100
dataset_names = ['email-Eu-core-temporal-Dept1', 'email-Eu-core', 'CA-GrQc']
index = 2
dataset_name = dataset_names[index]
nc_is_enabled = True
# Load the CSV file
#df_global = pd.read_csv(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\{dataset_name}\\{n_inits}\\GlobalKernelKMeans_Dataset_{dataset_name}_NC_{nc_is_enabled}_K_{K}_Inits_{n_inits}_Results.csv')
df_global_pp_batch = pd.read_csv(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\{dataset_name}\\{n_inits}\\GlobalKernelKMeans_Dataset_{dataset_name}_Sampling_batch_NC_{nc_is_enabled}_K_50_Inits_{n_inits}_Results.csv')
df_global_pp_sequential = pd.read_csv(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\{dataset_name}\\{n_inits}\\GlobalKernelKMeans_Dataset_{dataset_name}_Sampling_sequential_NC_{nc_is_enabled}_K_50_Inits_{n_inits}_Results.csv')
df_random = pd.read_csv(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\{dataset_name}\\{n_inits}\\KernelKMeans_Dataset_{dataset_name}_Init_random_K_50_Inits_{n_inits}_NC_{nc_is_enabled}_Results.csv')
df_pp = pd.read_csv(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\{dataset_name}\\{n_inits}\\KernelKMeans_Dataset_{dataset_name}_Init_k-means++_K_50_Inits_{n_inits}_NC_{nc_is_enabled}_Results.csv')
#df_forgy = pd.read_csv(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\{dataset_name}\\{n_inits}\\KernelKMeans_Dataset_{dataset_name}_Init_forgy_NC_{nc_is_enabled}_K_50_Inits_{n_inits}_Results.csv')

# %%
import pandas as pd
from matplotlib import rc as rc
from matplotlib import pyplot as plt
import numpy as np 
from matplotlib.lines import Line2D
import seaborn as sns
max_array_b = np.full(49, -100)
max_array_s = np.full(49, -100)
max_array_pp = np.full(49, -100)
max_array_rnd = np.full(49, -100)
array_b = np.empty((0, 0))
array_s = np.empty((0, 0))
array_pp = np.empty((0, 0))
array_rnd = np.empty((0, 0))
user = "maria"
K = 50
n_inits = 100
indexes = [0,1]
dataset_names = ['email-Eu-core-temporal-Dept1', 'email-Eu-core', 'CA-GrQc']
dataset_gammas = [1.1075595203585957, 0.2447219772863289, 1.7161230364840334, 3.633944119437154, 0.004945063173230718, 0.5238901719997593, 1.4534823391903635, 1.63528264957219]
problems = [False, True]
index = 5
problem_index = 1
for index in indexes:       
    dataset_name = dataset_names[index]
    problem = problems[problem_index]
    gamma = ""
    gamma = f"{dataset_gammas[index]}\\"
    # Load the CSV file
    df_global = pd.read_csv(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\{dataset_name}\\{n_inits}\\GlobalKernelKMeans_Dataset_{dataset_name}_NC_{problem}_K_{K}_Inits_{n_inits}_Results.csv')
    df_global_pp_batch = pd.read_csv(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\{dataset_name}\\{n_inits}\\GlobalKernelKMeans_Dataset_{dataset_name}_Sampling_batch_NC_{problem}_K_50_Inits_{n_inits}_Results.csv')
    df_global_pp_sequential = pd.read_csv(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\{dataset_name}\\{n_inits}\\GlobalKernelKMeans_Dataset_{dataset_name}_Sampling_sequential_NC_{problem}_K_50_Inits_{n_inits}_Results.csv')
    df_random = pd.read_csv(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\{dataset_name}\\{n_inits}\\KernelKMeans_Dataset_{dataset_name}_Init_random_K_50_Inits_{n_inits}_NC_{problem}_Results.csv')
    df_pp = pd.read_csv(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\{dataset_name}\\{n_inits}\\KernelKMeans_Dataset_{dataset_name}_Init_k-means++_K_50_Inits_{n_inits}_NC_{problem}_Results.csv')
    #df_forgy = pd.read_csv(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\{dataset_name}\\{kernel}\\{n_inits}\\KernelKMeans_Dataset_{dataset_name}_Init_forgy_NC_{nc_is_enabled}_{kernel}_K_50_Inits_{n_inits}_Results.csv')

    def percentage_error(base_mse, to_compare_mse):
        return ((to_compare_mse - base_mse) / (base_mse)) * 100
    max_array_b = np.maximum(percentage_error(df_global['MSE'], df_global_pp_batch['MSE']), max_array_b) 
    max_array_s = np.maximum(percentage_error(df_global['MSE'], df_global_pp_sequential['MSE']), max_array_s)
    max_array_pp = np.maximum(percentage_error(df_global['MSE'], df_pp['MSE']), max_array_pp) 
    max_array_rnd = np.maximum(percentage_error(df_global['MSE'], df_random['MSE']), max_array_rnd)
    array_b = np.append(percentage_error(df_global['MSE'], df_global_pp_batch['MSE']), array_b) 
    array_s = np.append(percentage_error(df_global['MSE'], df_global_pp_sequential['MSE']), array_s)
    array_pp = np.append(percentage_error(df_global['MSE'], df_pp['MSE']), array_pp) 
    array_rnd = np.append(percentage_error(df_global['MSE'], df_random['MSE']), array_rnd)

np.savetxt(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\Problem_{problem}_Batch_Max_Errors', max_array_b, delimiter=',')
np.savetxt(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\Problem_{problem}_Sequential_Max_Errors', max_array_s, delimiter=',')
np.savetxt(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\Problem_{problem}_PP_Max_Errors', max_array_pp, delimiter=',')
np.savetxt(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\Problem_{problem}_Rnd_Max_Errors', max_array_rnd, delimiter=',')
np.savetxt(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\Problem_{problem}_Batch_Total_Errors_Histogram', array_b, delimiter=',')
np.savetxt(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\Problem_{problem}_Sequential_Total_Errors_Histogram', array_s, delimiter=',')
np.savetxt(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\Problem_{problem}_PP_Total_Errors_Histogram', array_pp, delimiter=',')
np.savetxt(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\Problem_{problem}_Rnd_Total_Errors_Histogram', array_rnd, delimiter=',')
np.savetxt(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\Problem_{problem}_PP_Total_Errors_Histogram', array_pp, delimiter=',')

# %%
def percentage_error(base_mse, to_compare_mse):
    return ((to_compare_mse - base_mse) / (base_mse)) * 100

# %%
# List of DataFrames 
dfs = {'df_global': df_global, 'df_global_pp_batch': df_global_pp_batch, 'df_global_pp_sequential': df_global_pp_sequential, 'df_pp': df_pp, 'df_random': df_random}

# Iterate over the dictionary to sum the 'execution_time' column for each DataFrame
for df_name, df in dfs.items():
    total_execution_time = round(df['EXECUTION TIME'].sum()/60, 2)
    print(f"Total Execution Time for {df_name} (rounded): {total_execution_time}")

# %%
rc('mathtext', fontset = 'cm')

fig, ax1 = plt.subplots(figsize=(16, 8),)

centroids_range = np.arange(2, 51)
#ax1.set_yscale("log", base=10)
ax1.set_xticks(ticks=centroids_range)

for axis in ['top','bottom','left','right']:
    ax1.spines[axis].set_linewidth(2.0)

linestyle = 'solid'
linewidth = 5
markersize = 150

colors = sns.color_palette("muted", 5)

# Global k-means
#ax1.plot(centroids_range, percentage_error(df_global['MSE'], df_forgy['MSE']), linestyle=linestyle, linewidth=linewidth, c="tab:gray")
#ax1.scatter(centroids_range, percentage_error(df_global['MSE'], df_forgy['MSE']), label = "Forgy", s=markersize, c="tab:gray")

ax1.plot(centroids_range, percentage_error(df_global_pp_sequential['MSE'], df_random['MSE']), linestyle=linestyle, linewidth=linewidth, c=colors[4])
ax1.scatter(centroids_range, percentage_error(df_global_pp_sequential['MSE'], df_random['MSE']), label = "Random", s=markersize, c=colors[4])

ax1.plot(centroids_range, percentage_error(df_global_pp_sequential['MSE'], df_pp['MSE']), linestyle=linestyle, linewidth=linewidth, color=colors[3])
ax1.scatter(centroids_range, percentage_error(df_global_pp_sequential['MSE'], df_pp['MSE']), label="K$k$M$\mathbb{++}$", c=colors[3], s=markersize)

#ax1.plot(centroids_range, percentage_error(df_global['MSE'], df_global['MSE']), linestyle=linestyle, linewidth=linewidth, c=colors[2])
#ax1.scatter(centroids_range, percentage_error(df_global['MSE'], df_global['MSE']), label="GK$k$M", s=markersize, c=colors[2])

ax1.plot(centroids_range, percentage_error(df_global_pp_sequential['MSE'], df_global_pp_batch['MSE']), linestyle=linestyle, linewidth=linewidth, c=colors[0])
ax1.scatter(centroids_range, percentage_error(df_global_pp_sequential['MSE'], df_global_pp_batch['MSE']), label="GK$k$M$\mathbb{++}$(batch)", c=colors[0], s=markersize)

ax1.plot(centroids_range, percentage_error(df_global_pp_sequential['MSE'], df_global_pp_sequential['MSE']), linestyle=linestyle, linewidth=linewidth, c=colors[1])
ax1.scatter(centroids_range, percentage_error(df_global_pp_sequential['MSE'], df_global_pp_sequential['MSE']), label="GK$k$M$\mathbb{++}$(sequential)", c=colors[1], s=markersize)
if(nc_is_enabled):
    ax1.set_ylabel("Normalized Cut PE $(\%)$", fontsize=40)
else:    
    ax1.set_ylabel("Ratio Association PE $(\%)$", fontsize=40)
ax1.grid(True)

#leg_global = Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[2], label="GK$k$M", markeredgecolor=colors[2], markersize=20)
leg_global_pp_batch = Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[0], label="GK$k$M$\mathbb{++}$(b)", markeredgecolor=colors[0], markersize=20)
leg_global_pp_sequential = Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[1], label="GK$k$M$\mathbb{++}$(s)", markeredgecolor=colors[1], markersize=20)
leg_pp = Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[3], label="K$k$M$\mathbb{++}$", markeredgecolor=colors[3], markersize=20)
leg_random = Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[4], label="RK$k$M", markeredgecolor=colors[4], markersize=20)
#leg_forgy = Line2D([0], [0], marker='o', color='w', markerfacecolor='gray', label="Forgy", markeredgecolor='gray', markersize=20)
leg1 = ax1.legend(handles=[leg_global_pp_batch, leg_global_pp_sequential, leg_pp, leg_random],loc='upper left', framealpha=0.8, fontsize=30)

leg1.get_frame().set_linewidth(2.0)
leg1.get_frame().set_edgecolor("black")

plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
xticks = list(np.arange(5, 51, 5))
plt.xticks([2] + xticks)
#plt.ylim(bottom=0, top=10)
plt.xlabel("Number $k$ of Clusters", fontsize=40)
plt.tight_layout()
plt.savefig(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\{dataset_name}\\{n_inits}\\Dataset_{dataset_name}_NC_{nc_is_enabled}_Algorithms_Comparison_Graph.png')
plt.show()

# %%
rc('mathtext', fontset = 'cm')

fig, ax1 = plt.subplots(figsize=(16, 8),)

centroids_range = np.arange(2, 51)
# ax1 setting
ax1.set_xticks(ticks=centroids_range)


for axis in ['top','bottom','left','right']:
    ax1.spines[axis].set_linewidth(2.0)

linestyle = 'solid'
linewidth = 5
markersize = 150

# Global k-means
#ax1.plot(centroids_range, df_forgy['ITERATIONS'], linestyle=linestyle, linewidth=linewidth, c="tab:gray")
#ax1.scatter(centroids_range, df_forgy['ITERATIONS'], label = "Forgy", s=markersize, c="tab:gray")

ax1.plot(centroids_range, df_random['ITERATIONS'], linestyle=linestyle, linewidth=linewidth, c=colors[4])
ax1.scatter(centroids_range, df_random['ITERATIONS'], label = "Rnd Init", s=markersize, c=colors[4])

ax1.plot(centroids_range, df_pp['ITERATIONS'], linestyle=linestyle, linewidth=linewidth, color=colors[3])
ax1.scatter(centroids_range, df_pp['ITERATIONS'], label="K$k$M$\mathbb{++}$", c=colors[3], s=markersize)

#ax1.plot(centroids_range, df_global['ITERATIONS'], linestyle=linestyle, linewidth=linewidth, c=colors[2])
#ax1.scatter(centroids_range, df_global['ITERATIONS'], label="GK$k$M", s=markersize, c=colors[2])

ax1.plot(centroids_range, df_global_pp_batch['ITERATIONS'], linestyle=linestyle, linewidth=linewidth, c=colors[0])
ax1.scatter(centroids_range, df_global_pp_batch['ITERATIONS'], label="GK$k$M$\mathbb{++}$(batch)", c=colors[0], s=markersize)

ax1.plot(centroids_range, df_global_pp_sequential['ITERATIONS'], linestyle=linestyle, linewidth=linewidth, c=colors[1])
ax1.scatter(centroids_range, df_global_pp_sequential['ITERATIONS'], label="GK$k$M$\mathbb{++}$(sequential)", c=colors[1], s=markersize)
if(nc_is_enabled):
    ax1.set_ylabel("Average iterations", fontsize=40)
else:    
    ax1.set_ylabel("Average iterations", fontsize=40)
ax1.grid(True)

#leg_global = Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[2], label="GK$k$M", markeredgecolor=colors[2], markersize=20)
leg_global_pp_batch = Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[0], label="GK$k$M$\mathbb{++}$(b)", markeredgecolor=colors[0], markersize=20)
leg_global_pp_sequential = Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[1], label="GK$k$M$\mathbb{++}$(s)", markeredgecolor=colors[1], markersize=20)
leg_pp = Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[3], label="K$k$M$\mathbb{++}$", markeredgecolor=colors[3], markersize=20)
leg_random = Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[4], label="RK$k$M", markeredgecolor=colors[4], markersize=20)

leg1 = ax1.legend(handles=[leg_global_pp_batch, leg_global_pp_sequential, leg_pp, leg_random],loc='upper right', framealpha=0.8, fontsize=30)
leg1.get_frame().set_linewidth(2.0)
leg1.get_frame().set_edgecolor("black")

plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
xticks = list(np.arange(5, 51, 5))
plt.xticks([2] + xticks)

plt.xlabel("Number $k$ of Clusters", fontsize=40)
plt.tight_layout()
plt.savefig(f'C:\\Users\\{user}\\Documents\\GitHub\\global-kernel-k-means-pp\\Results\\{dataset_name}\\{n_inits}\\Dataset_{dataset_name}_NC_{nc_is_enabled}_Algorithms_Iteration_Comparison_Graph.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for BREAST CANCER dataset
kernels = ['Cosine', 'Laplacian', 'Rbf']
gl_times = [2.57 * 60, 1.46 * 60, 2.90 * 60]  # gl times in seconds
gl_b_times = [23.11, 15.76, 24.42]  # gl++(b) times in seconds
gl_s_times = [24.68, 16.31, 26.54]  # gl++(s) times in seconds
k_ms_times = [7.33*60, 6.47*60, 6.65*60]  # k-ms++ times in seconds
rnd_times = [1.45 * 60, 1.22 * 60, 1.45 * 60]  # rnd times in seconds

# Creating the plot
x = np.arange(len(kernels))  # label locations
width = 0.15  # width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - 2*width, gl_times, width, label='gl', edgecolor='black', c='tab:brown')
bars2 = ax.bar(x - width, gl_b_times, width, label='gl++(b)', edgecolor='black', c='tab:red')
bars3 = ax.bar(x, gl_s_times, width, label='gl++(s)', edgecolor='black', c="tab:green")
bars4 = ax.bar(x + width, k_ms_times, width, label='k-ms++', edgecolor='black')
bars5 = ax.bar(x + 2*width, rnd_times, width, label='rnd', edgecolor='black')


#ax1.plot(centroids_range, percentage_error(df_global['MSE'], df_global['MSE']), linestyle=linestyle, linewidth=linewidth, c="tab:green")
#ax1.scatter(centroids_range, percentage_error(df_global['MSE'], df_global['MSE']), label="global kernel $k$-means", s=markersize, c="tab:green")

#ax1.plot(centroids_range, percentage_error(df_global_pp_batch['MSE'], df_global_pp_batch['MSE']), linestyle=linestyle, linewidth=linewidth, c="tab:blue")
#ax1.scatter(centroids_range, percentage_error(df_global_pp_batch['MSE'], df_global_pp_batch['MSE']), label="global kernel $k$-means$\mathbb{++}$ (batch)", c="tab:blue", s=markersize)

#ax1.plot(centroids_range, percentage_error(df_global['MSE'], df_global_pp_sequential['MSE']), linestyle=linestyle, linewidth=linewidth, c="black")
#ax1.scatter(centroids_range, percentage_error(df_global['MSE'], df_global_pp_sequential['MSE']), label="global kernel $k$-means$\mathbb{++}$ (sequential)", c="black", s=markersize)

#ax1.plot(centroids_range, percentage_error(df_global_pp_batch['MSE'], df_pp['MSE']), linestyle=linestyle, linewidth=linewidth, color="tab:gray")
#ax1.scatter(centroids_range, percentage_error(df_global_pp_batch['MSE'], df_pp['MSE']), label="kernel $k$-means$\mathbb{++}$", c="tab:gray", s=markersize)

#ax1.plot(centroids_range, percentage_error(df_global_pp_batch['MSE'], df_random['MSE']), linestyle=linestyle, linewidth=linewidth, c="tab:red")
#ax1.scatter(centroids_range, percentage_error(df_global_pp_batch['MSE'], df_random['MSE']), label = "kernel $k$-means (random)", s=markersize, c="tab:red")

# Adding labels and title
ax.set_xlabel('Kernels')
ax.set_ylabel('Execution Time (s)')
ax.set_title('Execution Time Comparison - Breast Cancer Dataset')
ax.set_xticks(x)
ax.set_xticklabels(kernels)
ax.legend(edgecolor='black')

# Adding the grid
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Data for DERMATOLOGY dataset from the table
kernels = ['Cosine', 'Laplacian', 'Rbf']
gl_times = [32.88, 26.48, 1.47 * 60]  # gl times in seconds
gl_b_times = [8.23, 7.09, 8.47]  # gl++(b) times in seconds
gl_s_times = [9.44, 8.01, 9.63]  # gl++(s) times in seconds
k_ms_times = [3.24*60, 2.93*60, 3.01*60]  # k-ms++ times in seconds
rnd_times = [35.83, 33.86, 36.74]  # rnd times in seconds

# Creating the plot for DERMATOLOGY dataset
x = np.arange(len(kernels))  # label locations
width = 0.15  # width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - 2*width, gl_times, width, label='gl', edgecolor='black')
bars2 = ax.bar(x - width, gl_b_times, width, label='gl++(b)', edgecolor='black')
bars3 = ax.bar(x, gl_s_times, width, label='gl++(s)', edgecolor='black')
bars4 = ax.bar(x + width, k_ms_times, width, label='k-ms++', edgecolor='black')
bars5 = ax.bar(x + 2*width, rnd_times, width, label='rnd', edgecolor='black')

# Adding labels and title
ax.set_xlabel('Kernels')
ax.set_ylabel('Execution Time (s)')
ax.set_title('Execution Time Comparison - Dermatology Dataset')
ax.set_xticks(x)
ax.set_xticklabels(kernels)
ax.legend(edgecolor='black')

# Adding the grid
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for ECOLI dataset from the table
kernels = ['Cosine', 'Laplacian', 'Rbf']
gl_times = [47.01, 31.72, 43.88]  # gl times in seconds
gl_b_times = [12.47, 8.74, 11.95]# gl++(b) times in seconds
gl_s_times = [13.26, 9.74, 12.96]# gl++(s) times in seconds
k_ms_times = [2.78*60, 2.74*60, 2.77*60]  # k-ms++ times in seconds
rnd_times = [42.82, 35.44, 40.94]  # rnd times in seconds

# Creating the plot for ECOLI dataset
x = np.arange(len(kernels))  # label locations
width = 0.15  # width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - 2*width, gl_times, width, label='gl', edgecolor='black')
bars2 = ax.bar(x - width, gl_b_times, width, label='gl++(b)', edgecolor='black')
bars3 = ax.bar(x, gl_s_times, width, label='gl++(s)', edgecolor='black')
bars4 = ax.bar(x + width, k_ms_times, width, label='k-ms++', edgecolor='black')
bars5 = ax.bar(x + 2*width, rnd_times, width, label='rnd', edgecolor='black')

# Adding labels and title
ax.set_xlabel('Kernels')
ax.set_ylabel('Execution Time (s)')
ax.set_title('Execution Time Comparison - E. Coli Dataset')
ax.set_xticks(x)
ax.set_xticklabels(kernels)
ax.legend(edgecolor='black')

# Adding the grid
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for Iris dataset from the table
kernels = ['Cosine', 'Laplacian', 'Rbf']
gl_times = [9.73, 7.33, 9.02]  # gl times in seconds
gl_b_times = [6.42, 4.93, 6.08]# gl++(b) times in seconds
gl_s_times = [6.83, 5.51, 6.47]# gl++(s) times in seconds
k_ms_times = [59.55, 54.84, 58.85]  # k-ms++ times in seconds
rnd_times = [42.82, 35.44, 40.94]  # rnd times in seconds

# Creating the plot for Iris dataset
x = np.arange(len(kernels))  # label locations
width = 0.15  # width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - 2*width, gl_times, width, label='gl', edgecolor='black')
bars2 = ax.bar(x - width, gl_b_times, width, label='gl++(b)', edgecolor='black')
bars3 = ax.bar(x, gl_s_times, width, label='gl++(s)', edgecolor='black')
bars4 = ax.bar(x + width, k_ms_times, width, label='k-ms++', edgecolor='black')
bars5 = ax.bar(x + 2*width, rnd_times, width, label='rnd', edgecolor='black')

# Adding labels and title
ax.set_xlabel('Kernels')
ax.set_ylabel('Execution Time (s)')
ax.set_title('Execution Time Comparison - Iris Dataset')
ax.set_xticks(x)
ax.set_xticklabels(kernels)
ax.legend(edgecolor='black')

# Adding the grid
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for Olivetti Faces dataset from the table
kernels = ['Cosine', 'Laplacian', 'Rbf']
gl_times = [46.64, 36.13, 44.61]  # gl times in seconds
gl_b_times = [11.29, 9.3, 11.05]# gl++(b) times in seconds
gl_s_times = [12.41, 10.13, 13.06]# gl++(s) times in seconds
k_ms_times = [3.55*60, 3.41*60, 3.39*60]  # k-ms++ times in seconds
rnd_times = [49.83, 39.1, 44.64]  # rnd times in seconds

# Creating the plot for Wine dataset
x = np.arange(len(kernels))  # label locations
width = 0.15  # width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - 2*width, gl_times, width, label='gl', edgecolor='black')
bars2 = ax.bar(x - width, gl_b_times, width, label='gl++(b)', edgecolor='black')
bars3 = ax.bar(x, gl_s_times, width, label='gl++(s)', edgecolor='black')
bars4 = ax.bar(x + width, k_ms_times, width, label='k-ms++', edgecolor='black')
bars5 = ax.bar(x + 2*width, rnd_times, width, label='rnd', edgecolor='black')

# Adding labels and title
ax.set_xlabel('Kernels')
ax.set_ylabel('Execution Time (s)')
ax.set_title('Execution Time Comparison - Wine Dataset')
ax.set_xticks(x)
ax.set_xticklabels(kernels)
ax.legend(edgecolor='black')

# Adding the grid
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for Wine dataset from the table
kernels = ['Cosine', 'Laplacian', 'Rbf']
gl_times = [10.62, 7.42, 44.61]  # gl times in seconds
gl_b_times = [5.74, 4.64, 5.63]# gl++(b) times in seconds
gl_s_times = [6.23, 5.11, 6.08]# gl++(s) times in seconds
k_ms_times = [1.19*60, 1.13*60, 1.19*60]  # k-ms++ times in seconds
rnd_times = [19.19, 15.81, 19.47]  # rnd times in seconds

# Creating the plot for Wine dataset
x = np.arange(len(kernels))  # label locations
width = 0.15  # width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - 2*width, gl_times, width, label='gl', edgecolor='black')
bars2 = ax.bar(x - width, gl_b_times, width, label='gl++(b)', edgecolor='black')
bars3 = ax.bar(x, gl_s_times, width, label='gl++(s)', edgecolor='black')
bars4 = ax.bar(x + width, k_ms_times, width, label='k-ms++', edgecolor='black')
bars5 = ax.bar(x + 2*width, rnd_times, width, label='rnd', edgecolor='black')

# Adding labels and title
ax.set_xlabel('Kernels')
ax.set_ylabel('Execution Time (s)')
ax.set_title('Execution Time Comparison - Wine Dataset')
ax.set_xticks(x)
ax.set_xticklabels(kernels)
ax.legend(edgecolor='black')

# Adding the grid
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#   TO CHECK IT 
# Data for Waveform-V1 R dataset from the table
kernels = ['Cosine', 'Laplacian', 'Rbf']
#gl_times = [10.62, 7.42, 44.61]  # gl times in seconds
gl_b_times = [5.60, 1.26, 5.71]# gl++(b) times in seconds
gl_s_times = [5.58, 1.43, 5.74]# gl++(s) times in seconds
k_ms_times = [18.24, 17.21, 18.61]  # k-ms++ times in seconds
rnd_times = [27.31, 10.05, 11.70]  # rnd times in seconds

# Creating the plot for Waveform-V1 R dataset
x = np.arange(len(kernels))  # label locations
width = 0.15  # width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
#bars1 = ax.bar(x - 2*width, gl_times, width, label='gl', edgecolor='black')
bars2 = ax.bar(x - width, gl_b_times, width, label='gl++(b)', edgecolor='black', color='#ff7f0e')
bars3 = ax.bar(x, gl_s_times, width, label='gl++(s)', edgecolor='black', color='#2ca02c') 
bars4 = ax.bar(x + width, k_ms_times, width, label='k-ms++', edgecolor='black', color='#d62728')
bars5 = ax.bar(x + 2*width, rnd_times, width, label='rnd', edgecolor='black', color='#9467bd')

# Adding labels and title
ax.set_xlabel('Kernels')
ax.set_ylabel('Execution Time (h)')
ax.set_title('Execution Time Comparison - Waveform-V1 R Dataset')
ax.set_xticks(x)
ax.set_xticklabels(kernels)
ax.legend(edgecolor='black')

# Adding the grid
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#   TO CHECK IT 
# Data for Pendigits dataset from the table
kernels = ['Cosine', 'Laplacian', 'Rbf']
#gl_times = [10.62, 7.42, 44.61]  # gl times in seconds
gl_b_times = [1.97, 1.17, 2.02]# gl++(b) times in seconds
gl_s_times = [2.16, 1.19, 2.02]# gl++(s) times in seconds
k_ms_times = [5.22, 5.42, 5.57]  # k-ms++ times in seconds
rnd_times = [4.17, 3.70, 3.81]  # rnd times in seconds

# Creating the plot for Pendigits dataset
x = np.arange(len(kernels))  # label locations
width = 0.15  # width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
#bars1 = ax.bar(x - 2*width, gl_times, width, label='gl', edgecolor='black')
bars2 = ax.bar(x - width, gl_b_times, width, label='gl++(b)', edgecolor='black', color='#ff7f0e')
bars3 = ax.bar(x, gl_s_times, width, label='gl++(s)', edgecolor='black', color='#2ca02c') 
bars4 = ax.bar(x + width, k_ms_times, width, label='k-ms++', edgecolor='black', color='#d62728')
bars5 = ax.bar(x + 2*width, rnd_times, width, label='rnd', edgecolor='black', color='#9467bd')

# Adding labels and title
ax.set_xlabel('Kernels')
ax.set_ylabel('Execution Time (d)')
ax.set_title('Execution Time Comparison - Pendigits Dataset')
ax.set_xticks(x)
ax.set_xticklabels(kernels)
ax.legend(edgecolor='black')

# Adding the grid
ax.grid(True)

# Display the plot
plt.tight_layout()
plt.show()
